# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sg

# %%
data = np.loadtxt('2022-07-2518.51.46moreb10s.csv', skiprows=1, delimiter=',') 
fs = 1/(data[1,0] - data[0,0])

# %%
fs
# Out:
# 2057.6131687242787

# %%
zfig = plt.plot(data[:,0], data[:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#design a filter

#lowpass
b, a = signal.butter(10, 50, fs=fs, btype=lowpass)

#highpass

#bandpass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <module>
#       1 #design a filter
#       2
#       3 #lowpass
# ----> 4 b, a = signal.butter(10, 50, fs=fs, btype=lowpass)
#
# NameError: name 'signal' is not defined
